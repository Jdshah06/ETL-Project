# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine

# %%
pop_file = "data.csv"

pop_df = pd.read_csv(pop_file)

# %%
pop_df
# Out:
#     rank                 State       Pop  Growth   Pop2018   Pop2010  \
# 0      1            California  39937489  0.0096  39557045  37320903
# 1      2                 Texas  29472295  0.0268  28701845  25242679
# 2      3               Florida  21992985  0.0326  21299325  18845785
# 3      4              New York  19440469 -0.0052  19542209  19400080
# 4      5          Pennsylvania  12820878  0.0011  12807060  12711158
# 5      6              Illinois  12659682 -0.0064  12741080  12840762
# 6      7                  Ohio  11747694  0.0050  11689442  11539327
# 7      8               Georgia  10736059  0.0206  10519475   9711810
# 8      9        North Carolina  10611862  0.0220  10383620   9574293
# 9     10              Michigan  10045029  0.0049   9995915   9877535
# 10    11            New Jersey   8936574  0.0031   8908520   8799624
# 11    12              Virginia   8626207  0.0127   8517685   8023680
# 12    13            Washington   7797095  0.0347   7535591   6742902
# ...

# %%
pop_df = pop_df[['State','Pop','density']]
pop_df
# Out:
#                    State       Pop     density
# 0             California  39937489    256.3727
# 1                  Texas  29472295    112.8204
# 2                Florida  21992985    410.1256
# 3               New York  19440469    412.5211
# 4           Pennsylvania  12820878    286.5449
# 5               Illinois  12659682    228.0243
# 6                   Ohio  11747694    287.5038
# 7                Georgia  10736059    186.6719
# 8         North Carolina  10611862    218.2702
# 9               Michigan  10045029    177.6655
# 10            New Jersey   8936574   1215.1991
# 11              Virginia   8626207    218.4403
# 12            Washington   7797095    117.3272
# 13               Arizona   7378494     64.9550
# 14         Massachusetts   6976597    894.4355
# 15             Tennessee   6897576    167.2748
# 16               Indiana   6745354    188.2810
# 17              Missouri   6169270     89.7453
# 18              Maryland   6083116    626.6731
# ...

# %%
pop_df = pop_df.rename(columns={
    'State':'state',
    'Pop':'population',
    'density':'population_density'
})

# %%
pop_df
# Out:
#                    state  population  population_density
# 0             California    39937489            256.3727
# 1                  Texas    29472295            112.8204
# 2                Florida    21992985            410.1256
# 3               New York    19440469            412.5211
# 4           Pennsylvania    12820878            286.5449
# 5               Illinois    12659682            228.0243
# 6                   Ohio    11747694            287.5038
# 7                Georgia    10736059            186.6719
# 8         North Carolina    10611862            218.2702
# 9               Michigan    10045029            177.6655
# 10            New Jersey     8936574           1215.1991
# 11              Virginia     8626207            218.4403
# 12            Washington     7797095            117.3272
# 13               Arizona     7378494             64.9550
# 14         Massachusetts     6976597            894.4355
# ...

# %%
pop_df.to_csv('Pop_Stat.csv')

# %%
connection_string = connection_string = "postgres:postgres@localhost:5432/ETL_Proj"
engine = create_engine(f'postgresql://{connection_string}')

# %%
engine.table_names()
# Out:
# ['airport', 'confirmed', 'population']

# %%
pop_df.to_sql(name='population', con=engine, if_exists='append', index=False)
